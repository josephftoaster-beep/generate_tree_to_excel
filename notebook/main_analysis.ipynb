# %%
import sys
import pandas as pd
import os
import re
from datetime import datetime

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_root)
src_path = os.path.join(project_root, 'src')
sys.path.append(src_path)

from data_collector import generate_visual_tree_recursive
from excel_writer import write_trees_to_excel

PROJECT_PATH = r'C:\Users\robek\OneDrive\デスクトップ\windows編' 
OUTPUT_FILE = f'Project_Document_Breakdown_Recursive_{today}.xlsx'

# ツリー描画用の文字
SPACE = '    '
PIPE_SPACE = '│' + SPACE
PIPE_ITEM = '├── '
CORNER_ITEM = '└── '
FILE_ICON = '📄'
FOLDER_ICON = '📂'

tree_data = data_collector.generate_visual_tree_recursive(PROJECT_PATH)

if "エラー" in tree_data:
    print(f'処理中断：{tree_data["エラー"][0]}')
else:
    excel_writer.write_trees_to_excel(tree_data, OUTPUT_FILE)

print('--- 処理完了 ---')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 13
#      10 sys.path.append(src_path)
#      12 from data_collector import generate_visual_tree_recursive
# ---> 13 from excel_writer import write_trees_to_excel
#      15 PROJECT_PATH = r'C:\Users\robek\OneDrive\デスクトップ\windows編'
#      16 OUTPUT_FILE = f'Project_Document_Breakdown_Recursive_{today}.xlsx'
#
# File c:\Users\robek\Github\generate_tree_to_excel\src\excel_writer.py:1
# ----> 1 def write_trees_to_excel(folder_data, output_filepath=f'Project_Tree_Report_{today}.xlsx'):
#       2     """
#       3     フォルダ名:ツリーリストの辞書を受け取り、各フォルダ名をシート名としてExcelに書き出す関数。
#       4
#    (...)      7         output_filepath (str): 出力するExcelファイルのパスと名前。
#       8     """
#       9     print(f'📊 Excelファイルへの書き出しを開始します: {output_filepath}')
#
# NameError: name 'today' is not defined

# %%
# !pip install import-ipynb
# Out:
# Collecting import-ipynb
#   Downloading import_ipynb-0.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: IPython in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from import-ipynb) (9.4.0)
# Requirement already satisfied: nbformat in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from import-ipynb) (5.10.4)
# Requirement already satisfied: colorama in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from IPython->import-ipynb) (0.4.6)
# Requirement already satisfied: decorator in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from IPython->import-ipynb) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from IPython->import-ipynb) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from IPython->import-ipynb) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from IPython->import-ipynb) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from IPython->import-ipynb) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from IPython->import-ipynb) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from IPython->import-ipynb) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from IPython->import-ipynb) (5.14.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from nbformat->import-ipynb) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from nbformat->import-ipynb) (4.25.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from nbformat->import-ipynb) (5.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (311)
# Requirement already satisfied: wcwidth in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->import-ipynb) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from stack_data->IPython->import-ipynb) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from stack_data->IPython->import-ipynb) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\robek\appdata\local\programs\python\python313\lib\site-packages (from stack_data->IPython->import-ipynb) (0.2.3)
# Downloading import_ipynb-0.2-py3-none-any.whl (4.0 kB)
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.2
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
